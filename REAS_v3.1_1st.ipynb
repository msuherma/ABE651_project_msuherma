# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame
# %matplotlib inline

# %%
df=pd.read_csv("coal_power_emissions_2012_v1.csv", delimiter=";")
country= pd.read_csv('coal_power_emissions_2012_v1.csv', sep=';', index_col='ISO2')

# %%
df.head()
# Out:
#    UNITID  EMISSION_SOURCE_ID  FACILITY_ID ISO2       LONG        LAT  \
# 0    7421                  37           10   US -86.457596  33.244018
# 1    7422                  36           10   US -86.457596  33.244018
# 2    7423                  35           10   US -86.457596  33.244018
# 3    7424                  38           10   US -86.457596  33.244018
# 4    7425                2403           10   US -86.458100  33.244200
#
#         PLANT_FUEL  NET_ELECTRICITY_GENERATION_MWH  FUEL_INPUT_LHV_MJ  \
# 0  Bituminous coal                    1.099329e+06       1.246994e+10
# 1  Bituminous coal                    1.099329e+06       1.246994e+10
# 2  Bituminous coal                    1.099329e+06       1.246994e+10
# 3  Bituminous coal                    9.893959e+05       1.122294e+10
# 4  Bituminous coal                    3.847651e+06       4.364478e+10
#
#    NET_ELECTRICAL_EFFICIENCY  ...  DATA_QUALITY_PLANTS_EMISSION_SO2  \
# ...

# %%
len(df)
# Out:
# 7861

# %%
a=df.transpose()

# %%
a.head(50)
# Out:
#                                                      0                1     \
# UNITID                                               7421             7422
# EMISSION_SOURCE_ID                                     37               36
# FACILITY_ID                                            10               10
# ISO2                                                   US               US
# LONG                                             -86.4576         -86.4576
# LAT                                                33.244           33.244
# PLANT_FUEL                                Bituminous coal  Bituminous coal
# NET_ELECTRICITY_GENERATION_MWH                1.09933e+06      1.09933e+06
# FUEL_INPUT_LHV_MJ                             1.24699e+10      1.24699e+10
# NET_ELECTRICAL_EFFICIENCY                         0.31737          0.31737
# CHP_PLANT                                           False            False
# ...

# %%
idn=country.loc[["ID"]]

# %%
idn.head()
# Out:
#        UNITID  EMISSION_SOURCE_ID  FACILITY_ID        LONG       LAT  \
# ISO2
# ID    1200335                3244         1094  119.893090 -0.710811
# ID    1200336                3245         1094  119.893090 -0.710811
# ID    1186143                4003         1442  107.449940 -6.538681
# ID    1195319                4004         1442  107.449940 -6.538681
# ID    1237175                4183         1534  117.361648  2.045088
#
#            PLANT_FUEL  NET_ELECTRICITY_GENERATION_MWH  FUEL_INPUT_LHV_MJ  \
# ISO2
# ID    Bituminous coal                    63073.070641       8.659121e+08
# ID    Bituminous coal                    63073.070641       8.659121e+08
# ID    Bituminous coal                   105121.784402       1.500437e+09
# ID    Bituminous coal                   105121.784402       1.500437e+09
# ID    Bituminous coal                    29434.099633       4.135347e+08
#
#       NET_ELECTRICAL_EFFICIENCY  CHP_PLANT  ...  \
# ...

# %%
len(idn)
# Out:
# 91

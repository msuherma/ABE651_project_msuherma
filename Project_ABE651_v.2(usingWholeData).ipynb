# %%
import pandas as pd

# %%
#Reading the data using Pandas dataframe
df = pd.read_csv('World Powerplant by WRI.csv', #open the name of file using pandas
                 sep=',') #delimiter is ',' comma
df1 = pd.read_csv('World Powerplant by WRI.csv', #open the name of file using pandas
                 sep=',', #delimiter is ',' comma
                 index_col='country_long') #using 'country_long' as the index

# %%
len(df)
# Out:
# 29910

# %%
df_idn=df1.loc["Indonesia"]
df_sga=df1.loc["Singapore"]
df_mys=df1.loc["Malaysia"]
df_brn=df1.loc["Brunei Darussalam"]
df_phl=df1.loc["Philippines"]
df_vnm=df1.loc["Vietnam"]
df_mmr=df1.loc["Myanmar"]
df_tha=df1.loc["Thailand"]
df_khm=df1.loc["Cambodia"]
df_lao=df1.loc["Laos"]
#df_tim=df1.loc["Timor Leste"]

# %%
#List unique values in the df['country_long'] column
df.country_long.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antarctica',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahrain', 'Bangladesh', 'Belarus', 'Belgium', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Central African Republic', 'Chile', 'China', 'Colombia', 'Congo',
#        'Costa Rica', 'Cote DIvoire', 'Croatia', 'Cuba', 'Cyprus',
#        'Czech Republic', 'Democratic Republic of the Congo', 'Denmark',
#        'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Fiji', 'Finland', 'France', 'French Guiana', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Guinea', 'Guinea-Bissau', 'Guyana', 'Honduras', 'Hungary',
# ...

# %%
#checking country availability
df_lao
# Out:
#              country                      name   gppd_idnr  capacity_mw  \
# country_long
# Laos             LAO                    Hongsa  WRI1022391      1878.00
# Laos             LAO                  Houay Ho  WRI1001049       157.00
# Laos             LAO                  Nam Leuk  WRI1001050        60.00
# Laos             LAO               Nam Lik 1-2  WRI1026796       100.00
# Laos             LAO                  Nam Long  WRI1026797         5.00
# Laos             LAO                   Nam Nga  WRI1026798        14.50
# Laos             LAO              Nam Ngiep 3A  WRI1026799        44.00
# Laos             LAO                Nam Ngum 1  WRI1001051       155.00
# Laos             LAO                Nam Ngum 2  WRI1001059       735.00
# Laos             LAO              Nam Pha Gnai  WRI1026800        19.20
# Laos             LAO                 Nam Samoy  WRI1026801         5.00
# Laos             LAO                  Nam Sana  WRI1026802        14.00
# ...

# %%
df_idn_fuel=df1.loc["Indonesia",["primary_fuel","capacity_mw", "estimated_generation_gwh"]]

# %%
df_idn_fuel
# Out:
#              primary_fuel  capacity_mw  estimated_generation_gwh
# country_long
# Indonesia            Coal      195.000                799.943408
# Indonesia             Oil       56.284               2053.000439
# Indonesia            Coal       60.000                246.136433
# Indonesia           Hydro      180.000                598.000874
# Indonesia           Hydro      126.000                418.600612
# ...                   ...          ...                       ...
# Indonesia           Hydro       18.360                 60.996089
# Indonesia      Geothermal      110.000                822.786885
# Indonesia      Geothermal      227.000               1697.932936
# Indonesia           Hydro       54.000                179.400262
# Indonesia           Hydro        6.300                 20.930031
#
# [178 rows x 3 columns]

# %%
coal_idn=df_idn["primary_fuel"] == "Coal"
coal_idn=df_idn[coal_idn]
coal_idn
# Out:
#              country                               name   gppd_idnr  \
# country_long
# Indonesia        IDN       Amamapare Port power station  WRI1075798
# Indonesia        IDN              Amurang power station  WRI1075799
# Indonesia        IDN        Banten Serang power station  WRI1075800
# Indonesia        IDN           Batu Hijau power station  WRI1075801
# Indonesia        IDN       Celukan Bawang power station  WRI1075802
# ...              ...                                ...         ...
# Indonesia        IDN    Pekanbaru Tenayan power station  WRI1075813
# Indonesia        IDN        Perawang Mill power station  WRI1075814
# Indonesia        IDN  Purwakarta Indorama Power Station  WRI1075815
# Indonesia        IDN      Sulawesi Mining power station  WRI1075816
# Indonesia        IDN    Tanjung Awar-Awar power station  WRI1075817
#
#               capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# country_long
# ...

# %%
#List unique values in the df['primary_fuel'] column
df.primary_fuel.unique()
# Out:
# array(['Hydro', 'Gas', 'Other', 'Oil', 'Wind', 'Nuclear', 'Coal', 'Solar',
#        'Waste', 'Biomass', 'Wave and Tidal', 'Petcoke', 'Geothermal',
#        'Cogeneration', 'Storage'], dtype=object)

# %% [markdown]
# # Indonesia

# %%
hyd_idn=df_idn["primary_fuel"] == "Hydro"
hyd_idn=df_idn[hyd_idn]
gas_idn=df_idn["primary_fuel"] == "Gas"
gas_idn=df_idn[gas_idn]
otr_idn=df_idn["primary_fuel"] == "Other"
otr_idn=df_idn[otr_idn]
oil_idn=df_idn["primary_fuel"] == "Oil"
oil_idn=df_idn[oil_idn]
nuc_idn=df_idn["primary_fuel"] == "Nuclear"
nuc_idn=df_idn[nuc_idn]
sol_idn=df_idn["primary_fuel"] == "Solar"
sol_idn=df_idn[sol_idn]
was_idn=df_idn["primary_fuel"] == "Waste"
was_idn=df_idn[was_idn]
bio_idn=df_idn["primary_fuel"] == "Biomass"
bio_idn=df_idn[bio_idn]
wav_idn=df_idn["primary_fuel"] == "Wave and Tidal"
wav_idn=df_idn[wav_idn]
ptc_idn=df_idn["primary_fuel"] == "Petcoke"
ptc_idn=df_idn[ptc_idn]
geo_idn=df_idn["primary_fuel"] == "Geothermal"
geo_idn=df_idn[geo_idn]
cog_idn=df_idn["primary_fuel"] == "Cogeneration"
cog_idn=df_idn[cog_idn]
sto_idn=df_idn["primary_fuel"] == "Storage"
sto_idn=df_idn[sto_idn]

# %%
coal_idn.plot.scatter(x=str('commissioning_year'), y='capacity_mw', c='r', marker='+', s=50)

# %%
coal_idn.plot.scatter(x=str('year_of_capacity_data'), y='capacity_mw', c='r', marker='+', s=50)

# %%
df_idn.primary_fuel.unique()
# Out:
# array(['Coal', 'Oil', 'Hydro', 'Geothermal', 'Gas'], dtype=object)

# %% [markdown]
# # Singapore
#
# Using `.query('')` method

# %%
gas_sga=df_sga.query("primary_fuel == 'Gas'")
was_sga=df_sga.query("primary_fuel == 'Waste'")
oil_sga=df_sga.query("primary_fuel == 'Oil'")

# %%
df_sga.primary_fuel.unique()
# Out:
# array(['Gas', 'Waste', 'Oil'], dtype=object)

# %%
df_mys.primary_fuel.unique()
# Out:
# array(['Hydro', 'Solar', 'Gas', 'Coal', 'Oil', 'Biomass'], dtype=object)

# %% [markdown]
# # Malaysia

# %%
gas_mys=df_mys.query("primary_fuel == 'Gas'")
gas_mys=df_mys.query("primary_fuel == 'Gas'")
was_mys=df_mys.query("primary_fuel == 'Waste'")
oil_mys=df_mys.query("primary_fuel == 'Oil'")

# %% [markdown]
# #using two
# #gas_mys=df_mys.query("primary_fuel == 'Gas'" )
# Cek: Data Analysis with Pandas and Python, Boris Paskhaver
# https://learning.oreilly.com/videos/data-analysis-with/9781788622394/9781788622394-video5_15

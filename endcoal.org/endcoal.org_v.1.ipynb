# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame
# %matplotlib inline

# %%
df=pd.read_csv("New Coal Plants by Country (MW)													 - NewByYear.csv", delimiter=",", header=3)
df_country=pd.read_csv("New Coal Plants by Country (MW)													 - NewByYear.csv", delimiter=",", header=3, index_col='Country')
#country= pd.read_csv('Coal Plants by Country (MW) - Sheet1.csv', sep=';', index_col='ISO2')

# %%
len(df)
# Out:
# 111

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_t=df.transpose()
df_t
# Out:
#                      0        1          2              3            4    \
# Country            China    India  Indonesia  United States  South Korea
# 2006              77,769    2,357      1,980            574          500
# 2007              80,616    5,330        180          1,514        2,086
# 2008              61,089    5,442        367          1,584        1,500
# 2009              60,678    5,673        351          1,935        2,359
# 2010              63,879   12,197        646          5,878          250
# 2011              62,376   15,164      4,695          4,254          123
# 2012              52,049   17,961      4,045          3,953            0
# 2013              51,276   18,388      2,024          1,813           60
# 2014              38,697   20,643      1,080            106        1,800
# 2015              65,397   21,130      2,421             50            0
# 2016              47,355   18,965      1,569              0        5,486
# ...

# %%
df_t.to_csv("Transpose_New Coal Plants by Country (MW).csv")

# %%
df_t=pd.read_csv("Transpose_New Coal Plants by Country (MW).csv", delimiter=",", header=1)
len(df_t)
# Out:
# 15

# %%
list(df_t.columns.values)
# Out:
# ['year',
#  'China',
#  'India',
#  'Indonesia',
#  'United States',
#  'South Korea',
#  'Vietnam',
#  'Turkey',
#  'Germany',
#  'Malaysia',
#  'Japan',
#  'Philippines',
#  'Russia',
#  'Poland',
#  'Pakistan',
#  'South Africa',
#  'Taiwan',
#  'Chile',
#  'Netherlands',
#  'Morocco',
#  'Thailand',
#  'Brazil',
#  'Italy',
#  'Laos',
#  'Australia',
#  'Sri Lanka',
#  'Czech Republic',
#  'Bulgaria',
#  'North Korea',
#  'Guatemala',
#  'Kazakhstan',
#  'Mexico',
#  'Canada',
#  'Botswana',
#  'Slovenia',
#  'Colombia',
#  'Bangladesh',
#  'France',
#  'Cambodia',
#  'Panama',
#  'Tajikistan',
#  'Zambia',
#  'Bosnia & Herzegovina',
#  'Kyrgyzstan',
#  'Brunei',
#  'Mongolia',
#  'Uzbekistan',
#  'Madagascar',
#  'Mauritius',
#  'Honduras',
#  'Syria',
#  'Myanmar',
#  'Senegal',
#  'Zimbabwe',
#  'Jordan',
#  'Argentina',
#  'Reunion',
#  'Guadeloupe',
#  'Egypt',
#  'Malawi',
#  'Serbia',
#  'Mozambique',
#  'Nigeria',
#  'Tanzania',
#  'United Arab Emirates',
#  'Iran',
# ...

# %%
df_t = df_t.rename(columns={'Country': 'Year'})
df_t=df_t[:-1]
df_t=df_t.set_index('Year')
year =[2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
df_t.insert(0, 'year', year)

# %%
df_t = df_t.apply(pd.to_numeric, errors='ignore')

# %%
CH=df_t.set_index('year')['China']
#lines = plt.plot(x='year', y="China", data=df_t)

# %%
df_t.head()
# Out:
#       year   China   India Indonesia United States South Korea Vietnam Turkey  \
# Year
# 2006  2006  77,769   2,357     1,980           574         500     116  1,080
# 2007  2007  80,616   5,330       180         1,514       2,086     300     78
# 2008  2008  61,089   5,442       367         1,584       1,500       0      0
# 2009  2009  60,678   5,673       351         1,935       2,359     520    405
# 2010  2010  63,879  12,197       646         5,878         250     300  1,390
#
#      Germany Malaysia  ... Oman Sudan Hong Kong Ivory Coast Niger  \
# Year                   ...
# 2006       0      748  ...    0     0         0           0     0
# 2007       0    1,496  ...    0     0         0           0     0
# 2008       0        0  ...    0     0         0           0     0
# 2009       0    1,776  ...    0     0         0           0     0
# 2010      85        0  ...    0     0         0           0     0
#
# ...

# %%
df_t.plot(x = 'year', y='China', kind='line')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-207-51c1cb336cb3> in <module>
# ----> 1 df_t.plot(x = 'year', y='China', kind='line')
#
# ~/opt/anaconda3/envs/ABE651/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/opt/anaconda3/envs/ABE651/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...
